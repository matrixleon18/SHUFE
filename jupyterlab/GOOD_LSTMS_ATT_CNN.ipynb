# %%
# CNN + LSTM + Multi-Head-Attention + CNN 的结构

# %%
# 准备数据
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F
import numpy as np
import pandas as pd
import time
import random
import math
import matplotlib.pyplot as plt

# %%
np.random.seed(3)
torch.manual_seed(3)
torch.cuda.manual_seed(3)

# np.random.seed(1027)
# torch.manual_seed(1027)
# torch.cuda.manual_seed(1027)
torch.backends.cudnn.deterministic = True

# %%
# 设置 GPU 优先
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# 加载数据
dataset = pd.read_csv("601229.csv", index_col=0)
# dataset = pd.read_csv("601229_price_qfq_137dims.csv", index_col=0)
# dataset = pd.read_csv("601229.csv", index_col=0)
# dataset = dataset.drop(['date'], axis=1)
dataset = dataset.fillna(0)

# %%
# 将数据按照BATCH_SIZE的窗口进行滑动，每个窗口数据做一组
# # 数据转成sequence的格式，这里定义每个seq的长度
TRAIN_VALIDATION_RATIO = 0.9
TRAIN_BATCH_SIZE = 40                                                        # 注意：BATCH_SIZE是要能够整除(total_seq_count-1)的
TEST_BATCH_SIZE = 1
SEQ_LENGTH = 25
Y_SEQ_LEN = 1                                                         # 要用2个y来表示预测的第一天和预测的第二天，对应 "future" 和 "future2",每个y都是1-D的，y的seq_len是2
Y_DIM = 1
X_DIM = dataset.shape[1]-Y_SEQ_LEN                                    # 表示输入的sequence里每个element有122维度，也是encoder的input_dim

# 把数据切换成 BATCH_SIZE 的一个个batch
rolling_data = pd.DataFrame()
for i in dataset.rolling(SEQ_LENGTH):
    if i.shape[0] == SEQ_LENGTH:
        rolling_data = rolling_data.append(i)

rolling_data = rolling_data.values.reshape(-1, SEQ_LENGTH, X_DIM+Y_SEQ_LEN)                   # 数据一共是 seq_count x seq_len x (x_in_dim+Y_SEQ_LEN) 

print("rolling_data shape: {}".format(rolling_data.shape))
print("seq count: {}".format(rolling_data.shape[0]))                                       # 所以一共有 seq_count 列数据，每一行的数据是123维 （包括y）
print("seq length: {}".format(SEQ_LENGTH))

# TEST_BATCH_COUNT  = (rolling_data.shape[0])%TRAIN_BATCH_SIZE
TEST_BATCH_SIZE  = (rolling_data.shape[0])%TRAIN_BATCH_SIZE
if TEST_BATCH_SIZE == 0:                                                                   # 如果 rolling_data 刚好被整除，那就专门留一整块给test，全部算一个batch
    TEST_BATCH_SIZE = TRAIN_BATCH_SIZE
TEST_BATCH_COUNT = 1
TRAIN_BATCH_COUNT = int(((rolling_data.shape[0]-TEST_BATCH_SIZE*TEST_BATCH_COUNT)//TRAIN_BATCH_SIZE) * TRAIN_VALIDATION_RATIO)
VALID_BATCH_COUNT = int(((rolling_data.shape[0]-TEST_BATCH_SIZE*TEST_BATCH_COUNT)//TRAIN_BATCH_SIZE) - TRAIN_BATCH_COUNT)

print("TRAIN_BATCH_COUNT : {}".format(TRAIN_BATCH_COUNT))
print("VALID_BATCH_COUNT : {}".format(VALID_BATCH_COUNT))
print("TEST_BATCH_COUNT  : {}".format(TEST_BATCH_COUNT))

# train = rolling_data[:-test_seq_count].reshape(-1, BATCH_SIZE, SEQ_LENGTH, X_DIM+Y_SEQ_LEN)           # 把数据转成 tain_batch_count x BATCH_SIZE x seq_len x in_dim 格式
# test  = rolling_data[-test_seq_count:].reshape(-1, BATCH_SIZE, SEQ_LENGTH, X_DIM+Y_SEQ_LEN)           # 把数据转成 test_batch_count x BATCH_SIZE x seq_len x in_dim 格式

train = rolling_data[:TRAIN_BATCH_COUNT*TRAIN_BATCH_SIZE].reshape(TRAIN_BATCH_COUNT, TRAIN_BATCH_SIZE, SEQ_LENGTH, X_DIM+Y_DIM*Y_SEQ_LEN)                    # 把数据转成 tain_batch_count x TRAIN_BATCH_SIZE x seq_len x in_dim 格式
valid = rolling_data[TRAIN_BATCH_COUNT*TRAIN_BATCH_SIZE:-TEST_BATCH_COUNT*TEST_BATCH_SIZE].reshape(VALID_BATCH_COUNT, TRAIN_BATCH_SIZE, SEQ_LENGTH, X_DIM+Y_DIM*Y_SEQ_LEN)     # 把数据转成 tain_batch_count x TRAIN_BATCH_SIZE x seq_len x in_dim 格式
test  = rolling_data[-TEST_BATCH_COUNT*TEST_BATCH_SIZE:].reshape(TEST_BATCH_COUNT, TEST_BATCH_SIZE, SEQ_LENGTH, X_DIM+Y_DIM*Y_SEQ_LEN)                     # 把数据转成 test_batch_count x TEST_BATCH_SIZE x seq_len x in_dim 格式

TRAIN_BATCH_COUNT = train.shape[0]
TRAIN_BATCH_SIZE = train.shape[1]
VALID_BATCH_COUNT = valid.shape[0]
VALID_BATCH_SIZE = valid.shape[1]
TEST_BATCH_COUNT = test.shape[0]
TEST_BATCH_SIZE = test.shape[1]

train = torch.tensor(train)
valid = torch.tensor(valid)
test  = torch.tensor(test)


train_x, train_y = train[:,:,:,Y_SEQ_LEN:], train[:,:,-1:,0:Y_SEQ_LEN]           # [train_batch_count, batch_size, sequence_length, XorY dimission]
valid_x, valid_y = valid[:,:,:,Y_SEQ_LEN:], valid[:,:,-1:,0:Y_SEQ_LEN]           # [valid_batch_count, batch_size, sequence_length, XorY dimission]
test_x,  test_y  = test[:,:,:, Y_SEQ_LEN:],  test[:,:,-1:,0:Y_SEQ_LEN]           # [train_batch_count, batch_size, sequence_length, XorY dimission]

train_y = train_y.permute(0, 1, 3, 2)                                    # conver from [train_batch_count, batch_size, seq_length, y_seq_len]  to [train_batch_count, batch_size, y_seq_len, 1-dim]
valid_y = valid_y.permute(0, 1, 3, 2)                                    # conver from [train_batch_count, batch_size, seq_length, y_seq_len]  to [train_batch_count, batch_size, y_seq_len, 1-dim]
test_y  =  test_y.permute(0, 1, 3, 2)                                    # conver from [test_batch_count, batch_size, seq_length, y_seq_len]  to  [test_batch_count, batch_size, y_seq_len, 1-dim]


train_x = train_x.to(device)
train_y = train_y.to(device)
valid_x = valid_x.to(device)
valid_y = valid_y.to(device)
test_x = test_x.to(device)
test_y = test_y.to(device)

print("train_x: {}".format(train_x.shape))
print("train_y: {}".format(train_y.shape))
print("valid_x: {}".format(valid_x.shape))
print("valid_y: {}".format(valid_y.shape))
print("test_x:  {}".format(test_x.shape))
print("test_y:  {}".format(test_y.shape))
print("train_batch_count: {}".format(train.shape[0]))
print("valid_batch_count: {}".format(valid.shape[0]))
print("test_batch_count:  {}".format(test.shape[0]))
# Out:
# rolling_data shape: (1263, 25, 136)
# seq count: 1263
# seq length: 25
# TRAIN_BATCH_COUNT : 27
# VALID_BATCH_COUNT : 4
# TEST_BATCH_COUNT  : 1
# train_x: torch.Size([27, 40, 25, 135])
# train_y: torch.Size([27, 40, 1, 1])
# valid_x: torch.Size([4, 40, 25, 135])
# valid_y: torch.Size([4, 40, 1, 1])
# test_x:  torch.Size([1, 23, 25, 135])
# test_y:  torch.Size([1, 23, 1, 1])
# train_batch_count: 27
# valid_batch_count: 4
# test_batch_count:  1

# %%
# 定义 LSTM 模型

class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_dim_size, num_layers, output_size, attention_size=5, dropout=0.1):
        super().__init__()
        self.hidden_size = hidden_dim_size
        self.sequence_length = SEQ_LENGTH
        self.attention_size = attention_size
        self.num_layers = num_layers
        self.attention_size = attention_size    
        self.output_size = output_size
        
        self.conv1 = nn.Conv1d(input_size, 512, kernel_size=3, padding='same')        
        self.conv2 = nn.Conv1d(input_size, 512, kernel_size=5, padding='same')
        self.conv3 = nn.Conv1d(input_size, 512, kernel_size=7, padding='same')
        self.conv4 = nn.Conv1d(input_size, 512, kernel_size=9, padding='same')
        self.bn1 = nn.BatchNorm1d(256)  
        self.bn2 = nn.BatchNorm1d(self.hidden_size)
        
        self.conv01 = nn.Conv1d(input_size, 256, kernel_size=3, padding='same')        
        self.conv02 = nn.Conv1d(input_size, 256, kernel_size=5, padding='same')
        self.conv03 = nn.Conv1d(input_size, 256, kernel_size=7, padding='same')
        self.conv04 = nn.Conv1d(input_size, 256, kernel_size=9, padding='same')
          
            
        self.conv31 = nn.Conv1d(self.hidden_size, 512, kernel_size=3, padding='same')        
        self.conv32 = nn.Conv1d(512, 256, kernel_size=5, padding='same')
        self.conv33 = nn.Conv1d(256, 128, kernel_size=7, padding='same')
        self.conv34 = nn.Conv1d(128, 64, kernel_size=9, padding='same')
        self.linear35 = nn.Linear(64, self.output_size)    # 这个是给最后的多头注意力再乘 W0 的
        
                
        self.num_attention_head = 64                                                                  # 64
        self.attention_head_size = int(self.hidden_size/self.num_attention_head)                      # 每个头是32个维度
        self.all_head_size = self.num_attention_head * self.attention_head_size                       # 所有的头的维度合集
        
        self.dropout = nn.Dropout(dropout)
        
        self.layer_norm = nn.LayerNorm(self.hidden_size, elementwise_affine=False)
        
        self.lstm1 = nn.LSTM(input_size=input_size,       hidden_size=self.hidden_size, num_layers=self.num_layers, batch_first=True, dropout=dropout)
        self.lstm2 = nn.LSTM(input_size=self.hidden_size, hidden_size=self.hidden_size, num_layers=self.num_layers, batch_first=True, dropout=dropout)

        self.linear_1 = nn.Linear(input_size, self.hidden_size)          # 这个是将输入的维度转换成 hidden_dim 的
        self.linear_2 = nn.Linear(self.hidden_size, self.hidden_size)    # 这个是给最后的多头注意力再乘 W0 的
        self.linear_3 = nn.Linear(self.hidden_size, self.output_size)    # 这个是给最后的多头注意力再乘 W0 的
        
        self.relu = nn.LeakyReLU()                                       # 用 relu 来增强模型非线性
        self.tanh = nn.Tanh()
        
        # self.query = nn.Linear(self.hidden_size, self.hidden_size)     # 输入768， 输出多头的维度总数。这里还是768.
        # self.key = nn.Linear(self.hidden_size, self.hidden_size)       # 输入768， 输出多头的维度总数。这里还是768.
        # self.value = nn.Linear(self.hidden_size, self.hidden_size)     # 输入768， 输出多头的维度总数。这里还是768.
        
        self.query = nn.Linear(self.hidden_size, self.all_head_size)     # 输入768， 输出多头的维度总数。这里还是768.
        self.key = nn.Linear(self.hidden_size, self.all_head_size)       # 输入768， 输出多头的维度总数。这里还是768.
        self.value = nn.Linear(self.hidden_size, self.all_head_size)     # 输入768， 输出多头的维度总数。这里还是768.
        
  
        self.init_weights3()

    def init_weights1(self):
        for name, param in self.lstm1.named_parameters():
            if 'bias' in name:
                nn.init.constant_(param, 0.0)
            elif 'weight_ih' in name:
                nn.init.kaiming_normal_(param)
            elif 'weight_hh' in name:
                nn.init.orthogonal_(param)
        for name, param in self.lstm2.named_parameters():
            if 'bias' in name:
                nn.init.constant_(param, 0.0)
            elif 'weight_ih' in name:
                nn.init.kaiming_normal_(param)
            elif 'weight_hh' in name:
                nn.init.orthogonal_(param)
                
    def init_weights2(self):
        for name, param in self.lstm1.named_parameters():
            if 'bias' in name:
                nn.init.constant_(param, 0.0)
            elif 'weight_ih' in name:
                nn.init.kaiming_normal_(param)
            elif 'weight_hh' in name:
                nn.init.kaiming_normal_(param)    
        for name, param in self.lstm2.named_parameters():
            if 'bias' in name:
                nn.init.constant_(param, 0.0)
            elif 'weight_ih' in name:
                nn.init.kaiming_normal_(param)
            elif 'weight_hh' in name:
                nn.init.kaiming_normal_(param)    
                
    def init_weights3(self):
        for name, param in self.lstm1.named_parameters():
            if 'bias' in name:
                nn.init.constant_(param, 0.0)
            elif 'weight_ih' in name:
                nn.init.orthogonal_(param)
            elif 'weight_hh' in name:
                nn.init.orthogonal_(param)
        for name, param in self.lstm2.named_parameters():
            if 'bias' in name:
                nn.init.constant_(param, 0.0)
            elif 'weight_ih' in name:
                nn.init.orthogonal_(param)
            elif 'weight_hh' in name:
                nn.init.orthogonal_(param)
    
    def init_weights4(self):
        for name, param in self.lstm1.named_parameters():
            if 'bias' in name:
                nn.init.normal_(param, mean=0, std=1)
            elif 'weight_ih' in name:
                nn.init.orthogonal_(param)
            elif 'weight_hh' in name:
                nn.init.orthogonal_(param)
        for name, param in self.lstm2.named_parameters():
            if 'bias' in name:
                nn.init.normal_(param, mean=0, std=1)
            elif 'weight_ih' in name:
                nn.init.orthogonal_(param)
            elif 'weight_hh' in name:
                nn.init.orthogonal_(param)
    
    
    def conv_net(self, x):
        
        x = x.permute(0, 2, 1)
        
        x1 = self.relu(self.conv1(x))
        x1 = x1.permute(0, 2, 1)
        x1 = F.max_pool1d(x1, 2)
                
        x2 = self.relu(self.conv2(x))
        x2 = x2.permute(0, 2, 1)
        x2 = F.max_pool1d(x2, 2)

        x3 = self.relu(self.conv3(x))
        x3 = x3.permute(0, 2, 1)
        x3 = F.max_pool1d(x3, 2)
       
        x4 = self.relu(self.conv4(x))
        x4 = x4.permute(0, 2, 1)
        x4 = F.max_pool1d(x4, 2)
        
        
        x = torch.cat([x1, x2, x3, x4], 2)
               
        return x

    
    def conv_net2(self, x):
        
        x = x.permute(0, 2, 1)
        
        x1 = F.relu(self.conv01(x))
        x1 = x1.permute(0, 2, 1)
                
        x2 = F.relu(self.conv02(x))
        x2 = x2.permute(0, 2, 1)

        x3 = F.relu(self.conv03(x))
        x3 = x3.permute(0, 2, 1)
       
        x4 = F.relu(self.conv04(x))
        x4 = x4.permute(0, 2, 1)
        
        
        x = torch.cat([x1, x2, x3, x4], 2)
        
        return x

    def conv_net3(self, x):
        
        x = x.permute(0, 2, 1)
        
        x = F.relu(self.conv31(x))
        x = F.max_pool1d(x, 2)

        x = F.relu(self.conv32(x))
        x = F.max_pool1d(x, 2)
                
        x = F.relu(self.conv33(x))
        x = F.max_pool1d(x, 2)
        
        x = F.relu(self.conv34(x))
        x = F.max_pool1d(x, 2)
        
        
        x = x.permute(0, 2, 1)
        
        return x
    
    def attention_net(self, in_value, mask=None):
        # print(lstm_output.size())                                                   # [batch_size, seq_len, hidden_dim_size]
        # print(query.size())                                                         # [batch_size, seq_len, hidden_dim_size]
        # key   = lstm_output.transpose(1,2)
        # query = lstm_output
        # value = lstm_output
        batch_size = in_value.shape[0]
        seq_len = in_value.shape[1]
        hidden_dim = in_value.shape[2]
        
        # Q = self.query(in_value)
        # K = self.key(in_value)
        # V = self.value(in_value)
        # V = in_value
        
        # Q : [batch_size, seq_len, hidden_dim] ==> [batch_size, seq_len, num_head, head_size] ==> [batch_size, num_head, seq_len, head_size]
        Q = self.query(in_value).reshape(batch_size, seq_len, self.num_attention_head, self.attention_head_size).permute(0, 2, 1, 3)      # 先将 hidden_dim 切成 num_head * head_size ，再将 num_head 和 seq_len互换
        K = self.key(in_value).reshape(batch_size, seq_len, self.num_attention_head, self.attention_head_size).permute(0, 2, 1, 3)        # 先将 hidden_dim 切成 num_head * head_size ，再将 num_head 和 seq_len互换
        V = self.value(in_value).reshape(batch_size, seq_len, self.num_attention_head, self.attention_head_size).permute(0, 2, 1, 3)      # 先将 hidden_dim 切成 num_head * head_size ，再将 num_head 和 seq_len互换
        
        # d_k = Q.size(-1)                                                                            # d_k为query的维度。避免概率接近0
        
        # attention_scores = torch.matmul(query, lstm_output.transpose(1, 2)) / math.sqrt(d_k)     #打分机制  [batch_size, seq_len, hid_dim] * [batch_size, hid_dim, seq_len] ==> scores:[batch_size, seq_len, seq_len], 每个值就是两个输入x元素的相似性
        attention_scores = torch.matmul(Q, K.transpose(-1, -2))                                    # [batch_size, num_head, seq_len, head_size] * [batch_size, num_head, head_size, seq_len] ==> [batch_size, num_head, seq_len, seq_len]
        
        # attention_scores = attention_scores / math.sqrt(d_k)                                       # [batch_size, seq_len, seq_len]
        attention_scores = attention_scores / math.sqrt(self.attention_head_size)                  # 多头机制下，hidden-dim被划分为 num_head个区域，所以现在要除的就是每个小区域的维度开方
        
        # alpha = F.softmax(attention_scores, dim = -1)                                            #对最后一个维度归一化得分  [batch_size, seq_len, seq_len] 保证相似性在一行上归一了。
        alpha = nn.Softmax(dim=-1)(attention_scores)                                               # 因为alpha是方阵，0维的seq_len就是真正的序列长度，1维的seq_len是对应每一个element和序列元素相关性。
        
        # alpha = self.dropout(alpha)

        attention = torch.matmul(alpha, V)                                            # [batch_size, num_head, seq_len, seq_len] * [batch_size, num_head, seq_len, head_size] = [batch_size, num_head, seq_len, head_size]
        
        attention = attention.permute(0, 2, 1, 3).contiguous()                       # [batch_size, num_head, seq_len, head_size] ==> [batch_size, seq_len, num_head, head_size]
        # new_attention_shape = attention.size()[:-2] + (self.all_head_size,)
        # attention = attention.view(*new_attention_shape)
        attention = attention.reshape(batch_size, seq_len, self.all_head_size)
        
       
        attention = self.linear_2(attention)
        
        return attention      
        
    
    def forward(self, x, hidden, cell):
        
        x = x.float()
        
        lstm1_out, (h_n, c_n) = self.lstm1(x, (hidden, cell))
        
        lstm1_out = self.dropout(lstm1_out)
        
        lstm1_out,  (h_n, c_n) = self.lstm2(lstm1_out, (h_n, c_n))
        
        attn_output = self.attention_net(lstm1_out)       #和LSTM的不同就在于这一句
        
        # attn_output = self.dropout(attn_output)
        
        attn_output = self.conv_net3(attn_output)
        

        predictions = self.linear35(attn_output)
        
        
        return predictions, h_n, c_n

# %%
# 训练 LSTM 模型 ---- 这里的损失函数是计算Sequence最后一个元素的预测数据和真实数据差异

HIDDEN_SIZE = 1024
NUM_LAYERS = 2

def RMSELoss(yhat,y):
    return torch.sqrt(torch.mean((yhat-y)**2))

def R2_loss(y_pred, y_true):
    y_true_mean = torch.mean(y_true)
    ss_tot = torch.sum((y_true - y_true_mean) ** 2)
    ss_res = torch.sum((y_true - y_pred) ** 2)
    r2 = 1 - ss_res / ss_tot
    return r2

#MAPE——平均绝对百分比误差  mean_absolute_percent_error
def MAPE(y_pred ,y_true):
    absolute_percent_error = (torch.abs(y_pred-y_true)+1e-7)/(torch.abs(y_true)+1e-7)
    return torch.mean(absolute_percent_error)

model = LSTMModel(input_size=X_DIM, hidden_dim_size=HIDDEN_SIZE, num_layers=NUM_LAYERS, output_size=1).float().to(device)
LR = 1e-6
# loss_func = nn.MSELoss(reduction="mean")
loss_func = RMSELoss
optimizer = torch.optim.Adam(model.parameters(), lr=LR, weight_decay=1e-6)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=1, last_epoch=-1)

# %%
def ACC(y_hat, y_real):
    y_real = np.array(y_real) + 1
    y_hat = np.array(y_hat) + 1
    percentage = 1 - np.sqrt(np.mean(np.square((y_real - y_hat) / y_real)))
    return percentage * 100

# 定义 RMSE 损失函数。因为torch没有。
def RMSE(y_hat, y):
    return torch.sqrt(torch.mean((y_hat-y)**2))


# 定义 MAPE 计算函数。平均绝对百分比误差：不受量纲影响。但y接近0时受极端值影响。为（0%）表示完美模型，MAPE 大于 （100%）则表示劣质模型。
def MAPE(y_hat, y):
    absolute_percent_error = (torch.abs(y_hat-y)+1e-7)/(torch.abs(y)+1e-7)
    return torch.mean(absolute_percent_error)

# 定义了 R2 的计算函数。决定系数：反映因变量的全部变异能通过回归关系被自变量解释的比例。
# R2<=1，R2为1时说明预测模型不犯任何错误；R2为0时说明预测模型等于基准模型；R2小于0说明预测模型不如基准模型，可能数据不存在任何线性关系。
def R2(y_hat, y):
    y_mean = torch.mean(y)
    ss_tot = torch.sum((y - y_mean) ** 2)
    ss_res = torch.sum((y - y_hat) ** 2)
    r2 = 1 - ss_res / ss_tot
    return r2

# 定义 SMAPE 计算函数。修复了原始MAPE的缺点-它同时具有下限（0％）和上限（200％)
def SMAPE(y_hat, y):
    absolute_percent_error = (torch.abs(y_hat-y)+1e-7)/(torch.abs(y_hat)+torch.abs(y)+1e-7)
    return 2.0 * torch.mean(absolute_percent_error)



# 训练 LSTM 模型;  ---- 这里的损失函数是计算Sequence最后一个元素的预测数据和真实数据差异
model.train()
epochs = 2000
train_epoch_loss = 0
train_epoch_loss_list = []
train_epoch_acc_list = []
valid_epoch_loss = 0
valid_epoch_loss_list = []
valid_epoch_acc_list = []

train_batch_count = train_x.shape[0]
valid_batch_count = valid_x.shape[0]

h0 = torch.zeros(NUM_LAYERS, TRAIN_BATCH_SIZE, HIDDEN_SIZE).float().to(device)
c0 = torch.zeros(NUM_LAYERS, TRAIN_BATCH_SIZE, HIDDEN_SIZE).float().to(device)


for epoch in range(epochs):
    batch_loss = []
    batch_mape = []
    batch_r2   = []
    train_epoch_loss = 0
    train_epoch_mape = 0
    train_epoch_r2 = 0
    train_pred_value_list = []
    train_real_value_list = []
    train_batch_list = list(range(0, train_batch_count))
    # random.shuffle(train_batch_list)
    for step in train_batch_list:
        train_pred, hn, cn = model(train_x[step], h0, c0)                                                    # pred: [batch_size, seq_len, out_dim]  但被修改成了 [batch_size, 1, out_dim]
        loss = loss_func(train_pred[:, -1, -1], train_y[step][:, -1, -1])                                    # 取batch里每个sequence最后一个预测输出来和实际
        train_pred_value_list.extend(list(train_pred[:, -1, -1].cpu().detach().flatten().numpy() ))
        train_real_value_list.extend(list(train_y[step][:, -1, -1].cpu().detach().flatten().numpy() ))
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=20, norm_type=2)
        optimizer.step()
        batch_loss.append(loss.cpu().data.numpy())
        batch_mape.append(MAPE(train_pred[:, -1, -1], train_y[step][:, -1, -1]).item())
        batch_r2.append(R2(train_pred[:, -1, -1], train_y[step][:, -1, -1]).item())
    # print(batch_mape)
    train_epoch_loss = np.mean(batch_loss)
    train_epoch_mape = np.mean(batch_mape)
    train_epoch_r2 = np.mean(batch_r2)

    batch_loss = []
    batch_mape = []
    batch_r2 = []
    valid_epoch_loss = 0
    valid_epoch_mape = 0
    valid_epoch_r2 = 0
    valid_pred_value_list = []
    valid_real_value_list = []
    for step in range(valid_batch_count):
        valid_pred, hn, cn = model(valid_x[step], h0, c0)
        loss = loss_func(valid_pred[:, -1, -1], valid_y[step][:, -1, -1])
        valid_pred_value_list.extend(list(valid_pred[:, -1, -1].cpu().detach().flatten().numpy()))
        valid_real_value_list.extend(list(valid_y[step][ :, -1, -1].cpu().detach().flatten().numpy()))
        batch_loss.append(loss.cpu().data.numpy())
        batch_mape.append(MAPE(valid_pred[:, -1, -1], valid_y[step][:, -1, -1]).item())
        batch_r2.append(R2(valid_pred[:, -1, -1], valid_y[step][:, -1, -1]).item())
    # print(batch_loss)
    valid_epoch_loss = np.mean(batch_loss)
    valid_epoch_mape = np.mean(batch_mape)
    valid_epoch_r2 = np.mean(batch_r2)


    valid_epoch_loss_list.append(valid_epoch_loss)
    train_epoch_loss_list.append(train_epoch_loss)

    if ((epoch+1) % 10) == 0:
        print("{} of {} epoch \t train_loss: {:.3f} \t train_MAPE: {:.2%} \t train_r2: {:.3f} \t valid_loss: {:.3f} \t valid_MAPE: {:.2%} \t valid_r2: {:.3f}".format(epoch, epochs, train_epoch_loss, train_epoch_mape, train_epoch_r2, valid_epoch_loss, valid_epoch_mape, valid_epoch_r2))

    if valid_epoch_loss < 0.08:
        print("{} of {} epoch \t train_loss: {:.3f} \t train_MAPE: {:.2%} \t train_r2: {:.3f} \t valid_loss: {:.3f} \t valid_MAPE: {:.2%} \t valid_r2: {:.3f}".format(epoch, epochs, train_epoch_loss, train_epoch_mape, train_epoch_r2, valid_epoch_loss, valid_epoch_mape, valid_epoch_r2))
        print("****************************************** STOP TRAIN  ****************************************")
        break

plt.plot(train_epoch_loss_list, 'r-')
plt.plot(valid_epoch_loss_list, 'b-')
plt.show()
print("min train loss: {:.3f}".format(min(train_epoch_loss_list)))
print("min valid loss: {:.3f}".format(min(valid_epoch_loss_list)))
# Out:
# 9 of 2000 epoch 	 train_loss: 7.781 	 train_MAPE: 98.63% 	 train_r2: -1958.185 	 valid_loss: 7.004 	 valid_MAPE: 98.47% 	 valid_r2: -8476.034
# 19 of 2000 epoch 	 train_loss: 5.935 	 train_MAPE: 75.10% 	 train_r2: -1117.242 	 valid_loss: 4.389 	 valid_MAPE: 61.63% 	 valid_r2: -3356.260
# 29 of 2000 epoch 	 train_loss: 0.449 	 train_MAPE: 5.20% 	 train_r2: -6.673 	 valid_loss: 0.765 	 valid_MAPE: 10.84% 	 valid_r2: -82.997
# 39 of 2000 epoch 	 train_loss: 0.434 	 train_MAPE: 5.00% 	 train_r2: -6.139 	 valid_loss: 0.741 	 valid_MAPE: 10.49% 	 valid_r2: -78.891
# 49 of 2000 epoch 	 train_loss: 0.418 	 train_MAPE: 4.79% 	 train_r2: -5.599 	 valid_loss: 0.712 	 valid_MAPE: 10.07% 	 valid_r2: -74.331
# 59 of 2000 epoch 	 train_loss: 0.404 	 train_MAPE: 4.60% 	 train_r2: -5.180 	 valid_loss: 0.689 	 valid_MAPE: 9.73% 	 valid_r2: -71.045
# 69 of 2000 epoch 	 train_loss: 0.393 	 train_MAPE: 4.48% 	 train_r2: -4.916 	 valid_loss: 0.670 	 valid_MAPE: 9.44% 	 valid_r2: -67.867
# 79 of 2000 epoch 	 train_loss: 0.384 	 train_MAPE: 4.37% 	 train_r2: -4.676 	 valid_loss: 0.652 	 valid_MAPE: 9.17% 	 valid_r2: -64.621
# 89 of 2000 epoch 	 train_loss: 0.375 	 train_MAPE: 4.27% 	 train_r2: -4.513 	 valid_loss: 0.642 	 valid_MAPE: 9.02% 	 valid_r2: -62.616
# 99 of 2000 epoch 	 train_loss: 0.367 	 train_MAPE: 4.18% 	 train_r2: -4.354 	 valid_loss: 0.638 	 valid_MAPE: 8.97% 	 valid_r2: -62.301
# 109 of 2000 epoch 	 train_loss: 0.359 	 train_MAPE: 4.09% 	 train_r2: -4.199 	 valid_loss: 0.633 	 valid_MAPE: 8.88% 	 valid_r2: -61.266
# 119 of 2000 epoch 	 train_loss: 0.351 	 train_MAPE: 4.00% 	 train_r2: -4.043 	 valid_loss: 0.626 	 valid_MAPE: 8.78% 	 valid_r2: -59.804
# 129 of 2000 epoch 	 train_loss: 0.342 	 train_MAPE: 3.90% 	 train_r2: -3.850 	 valid_loss: 0.609 	 valid_MAPE: 8.55% 	 valid_r2: -56.472
# 139 of 2000 epoch 	 train_loss: 0.333 	 train_MAPE: 3.79% 	 train_r2: -3.656 	 valid_loss: 0.588 	 valid_MAPE: 8.25% 	 valid_r2: -52.257
# 149 of 2000 epoch 	 train_loss: 0.324 	 train_MAPE: 3.69% 	 train_r2: -3.462 	 valid_loss: 0.567 	 valid_MAPE: 7.95% 	 valid_r2: -48.281
# 159 of 2000 epoch 	 train_loss: 0.315 	 train_MAPE: 3.58% 	 train_r2: -3.261 	 valid_loss: 0.547 	 valid_MAPE: 7.66% 	 valid_r2: -44.698
# 169 of 2000 epoch 	 train_loss: 0.306 	 train_MAPE: 3.47% 	 train_r2: -3.084 	 valid_loss: 0.523 	 valid_MAPE: 7.31% 	 valid_r2: -40.198
# 179 of 2000 epoch 	 train_loss: 0.298 	 train_MAPE: 3.37% 	 train_r2: -2.888 	 valid_loss: 0.504 	 valid_MAPE: 7.04% 	 valid_r2: -37.189
# 189 of 2000 epoch 	 train_loss: 0.289 	 train_MAPE: 3.27% 	 train_r2: -2.716 	 valid_loss: 0.486 	 valid_MAPE: 6.79% 	 valid_r2: -34.232
# 199 of 2000 epoch 	 train_loss: 0.281 	 train_MAPE: 3.16% 	 train_r2: -2.538 	 valid_loss: 0.466 	 valid_MAPE: 6.49% 	 valid_r2: -31.062
# 209 of 2000 epoch 	 train_loss: 0.272 	 train_MAPE: 3.06% 	 train_r2: -2.372 	 valid_loss: 0.446 	 valid_MAPE: 6.21% 	 valid_r2: -28.334
# 219 of 2000 epoch 	 train_loss: 0.264 	 train_MAPE: 2.96% 	 train_r2: -2.178 	 valid_loss: 0.428 	 valid_MAPE: 5.94% 	 valid_r2: -25.841
# 229 of 2000 epoch 	 train_loss: 0.255 	 train_MAPE: 2.86% 	 train_r2: -2.004 	 valid_loss: 0.408 	 valid_MAPE: 5.66% 	 valid_r2: -23.108
# 239 of 2000 epoch 	 train_loss: 0.246 	 train_MAPE: 2.74% 	 train_r2: -1.810 	 valid_loss: 0.389 	 valid_MAPE: 5.40% 	 valid_r2: -21.075
# 249 of 2000 epoch 	 train_loss: 0.237 	 train_MAPE: 2.63% 	 train_r2: -1.634 	 valid_loss: 0.374 	 valid_MAPE: 5.17% 	 valid_r2: -19.059
# 259 of 2000 epoch 	 train_loss: 0.227 	 train_MAPE: 2.52% 	 train_r2: -1.452 	 valid_loss: 0.353 	 valid_MAPE: 4.88% 	 valid_r2: -17.065
# 269 of 2000 epoch 	 train_loss: 0.216 	 train_MAPE: 2.39% 	 train_r2: -1.266 	 valid_loss: 0.324 	 valid_MAPE: 4.44% 	 valid_r2: -14.282
# 279 of 2000 epoch 	 train_loss: 0.204 	 train_MAPE: 2.24% 	 train_r2: -0.975 	 valid_loss: 0.297 	 valid_MAPE: 4.06% 	 valid_r2: -11.502
# 289 of 2000 epoch 	 train_loss: 0.193 	 train_MAPE: 2.10% 	 train_r2: -0.730 	 valid_loss: 0.279 	 valid_MAPE: 3.80% 	 valid_r2: -10.008
# 299 of 2000 epoch 	 train_loss: 0.184 	 train_MAPE: 2.00% 	 train_r2: -0.512 	 valid_loss: 0.261 	 valid_MAPE: 3.55% 	 valid_r2: -8.459
# 309 of 2000 epoch 	 train_loss: 0.179 	 train_MAPE: 1.92% 	 train_r2: -0.371 	 valid_loss: 0.247 	 valid_MAPE: 3.32% 	 valid_r2: -7.427
# 319 of 2000 epoch 	 train_loss: 0.172 	 train_MAPE: 1.84% 	 train_r2: -0.235 	 valid_loss: 0.231 	 valid_MAPE: 3.11% 	 valid_r2: -6.228
# 329 of 2000 epoch 	 train_loss: 0.167 	 train_MAPE: 1.79% 	 train_r2: -0.109 	 valid_loss: 0.210 	 valid_MAPE: 2.78% 	 valid_r2: -4.821
# 339 of 2000 epoch 	 train_loss: 0.163 	 train_MAPE: 1.73% 	 train_r2: -0.038 	 valid_loss: 0.191 	 valid_MAPE: 2.49% 	 valid_r2: -3.610
# 349 of 2000 epoch 	 train_loss: 0.160 	 train_MAPE: 1.70% 	 train_r2: 0.008 	 valid_loss: 0.198 	 valid_MAPE: 2.59% 	 valid_r2: -3.928
# 359 of 2000 epoch 	 train_loss: 0.156 	 train_MAPE: 1.65% 	 train_r2: 0.053 	 valid_loss: 0.175 	 valid_MAPE: 2.26% 	 valid_r2: -2.850
# 369 of 2000 epoch 	 train_loss: 0.150 	 train_MAPE: 1.58% 	 train_r2: 0.158 	 valid_loss: 0.166 	 valid_MAPE: 2.11% 	 valid_r2: -2.338
# 379 of 2000 epoch 	 train_loss: 0.139 	 train_MAPE: 1.42% 	 train_r2: 0.307 	 valid_loss: 0.128 	 valid_MAPE: 1.53% 	 valid_r2: -0.984
# 389 of 2000 epoch 	 train_loss: 0.134 	 train_MAPE: 1.37% 	 train_r2: 0.353 	 valid_loss: 0.117 	 valid_MAPE: 1.37% 	 valid_r2: -0.628
# 399 of 2000 epoch 	 train_loss: 0.130 	 train_MAPE: 1.31% 	 train_r2: 0.404 	 valid_loss: 0.105 	 valid_MAPE: 1.22% 	 valid_r2: -0.374
# 409 of 2000 epoch 	 train_loss: 0.128 	 train_MAPE: 1.28% 	 train_r2: 0.426 	 valid_loss: 0.102 	 valid_MAPE: 1.21% 	 valid_r2: -0.286
# 419 of 2000 epoch 	 train_loss: 0.126 	 train_MAPE: 1.26% 	 train_r2: 0.428 	 valid_loss: 0.100 	 valid_MAPE: 1.13% 	 valid_r2: -0.207
# 429 of 2000 epoch 	 train_loss: 0.121 	 train_MAPE: 1.22% 	 train_r2: 0.468 	 valid_loss: 0.100 	 valid_MAPE: 1.13% 	 valid_r2: -0.307
# 439 of 2000 epoch 	 train_loss: 0.121 	 train_MAPE: 1.19% 	 train_r2: 0.486 	 valid_loss: 0.096 	 valid_MAPE: 1.10% 	 valid_r2: -0.136
# 449 of 2000 epoch 	 train_loss: 0.119 	 train_MAPE: 1.18% 	 train_r2: 0.515 	 valid_loss: 0.101 	 valid_MAPE: 1.17% 	 valid_r2: -0.327
# 459 of 2000 epoch 	 train_loss: 0.115 	 train_MAPE: 1.14% 	 train_r2: 0.554 	 valid_loss: 0.102 	 valid_MAPE: 1.18% 	 valid_r2: -0.358
# 469 of 2000 epoch 	 train_loss: 0.117 	 train_MAPE: 1.16% 	 train_r2: 0.533 	 valid_loss: 0.106 	 valid_MAPE: 1.22% 	 valid_r2: -0.582
# 479 of 2000 epoch 	 train_loss: 0.112 	 train_MAPE: 1.09% 	 train_r2: 0.591 	 valid_loss: 0.108 	 valid_MAPE: 1.23% 	 valid_r2: -0.709
# 489 of 2000 epoch 	 train_loss: 0.113 	 train_MAPE: 1.11% 	 train_r2: 0.576 	 valid_loss: 0.106 	 valid_MAPE: 1.19% 	 valid_r2: -0.606
# 499 of 2000 epoch 	 train_loss: 0.114 	 train_MAPE: 1.12% 	 train_r2: 0.564 	 valid_loss: 0.103 	 valid_MAPE: 1.15% 	 valid_r2: -0.457
# 509 of 2000 epoch 	 train_loss: 0.111 	 train_MAPE: 1.09% 	 train_r2: 0.613 	 valid_loss: 0.104 	 valid_MAPE: 1.17% 	 valid_r2: -0.537
# 519 of 2000 epoch 	 train_loss: 0.110 	 train_MAPE: 1.08% 	 train_r2: 0.629 	 valid_loss: 0.107 	 valid_MAPE: 1.17% 	 valid_r2: -0.685
# 529 of 2000 epoch 	 train_loss: 0.118 	 train_MAPE: 1.17% 	 train_r2: 0.522 	 valid_loss: 0.099 	 valid_MAPE: 1.11% 	 valid_r2: -0.453
# 539 of 2000 epoch 	 train_loss: 0.113 	 train_MAPE: 1.11% 	 train_r2: 0.610 	 valid_loss: 0.141 	 valid_MAPE: 1.64% 	 valid_r2: -1.989
# 549 of 2000 epoch 	 train_loss: 0.111 	 train_MAPE: 1.08% 	 train_r2: 0.604 	 valid_loss: 0.112 	 valid_MAPE: 1.27% 	 valid_r2: -0.956
# 559 of 2000 epoch 	 train_loss: 0.112 	 train_MAPE: 1.08% 	 train_r2: 0.616 	 valid_loss: 0.115 	 valid_MAPE: 1.29% 	 valid_r2: -0.948
# 569 of 2000 epoch 	 train_loss: 0.112 	 train_MAPE: 1.09% 	 train_r2: 0.623 	 valid_loss: 0.146 	 valid_MAPE: 1.74% 	 valid_r2: -2.353
# 579 of 2000 epoch 	 train_loss: 0.111 	 train_MAPE: 1.09% 	 train_r2: 0.616 	 valid_loss: 0.133 	 valid_MAPE: 1.53% 	 valid_r2: -1.847
# 589 of 2000 epoch 	 train_loss: 0.112 	 train_MAPE: 1.10% 	 train_r2: 0.619 	 valid_loss: 0.139 	 valid_MAPE: 1.60% 	 valid_r2: -2.072
# 599 of 2000 epoch 	 train_loss: 0.114 	 train_MAPE: 1.13% 	 train_r2: 0.600 	 valid_loss: 0.139 	 valid_MAPE: 1.59% 	 valid_r2: -2.199
# 609 of 2000 epoch 	 train_loss: 0.114 	 train_MAPE: 1.11% 	 train_r2: 0.614 	 valid_loss: 0.128 	 valid_MAPE: 1.44% 	 valid_r2: -1.661
# 619 of 2000 epoch 	 train_loss: 0.122 	 train_MAPE: 1.21% 	 train_r2: 0.534 	 valid_loss: 0.127 	 valid_MAPE: 1.47% 	 valid_r2: -1.653
# 629 of 2000 epoch 	 train_loss: 0.215 	 train_MAPE: 2.44% 	 train_r2: -0.677 	 valid_loss: 0.092 	 valid_MAPE: 1.06% 	 valid_r2: -0.248
# 639 of 2000 epoch 	 train_loss: 0.162 	 train_MAPE: 1.73% 	 train_r2: 0.180 	 valid_loss: 0.104 	 valid_MAPE: 1.21% 	 valid_r2: -0.634
# 649 of 2000 epoch 	 train_loss: 0.118 	 train_MAPE: 1.17% 	 train_r2: 0.554 	 valid_loss: 0.116 	 valid_MAPE: 1.34% 	 valid_r2: -1.050
# 659 of 2000 epoch 	 train_loss: 0.115 	 train_MAPE: 1.12% 	 train_r2: 0.598 	 valid_loss: 0.149 	 valid_MAPE: 1.77% 	 valid_r2: -2.583
# 669 of 2000 epoch 	 train_loss: 0.158 	 train_MAPE: 1.67% 	 train_r2: 0.169 	 valid_loss: 0.110 	 valid_MAPE: 1.28% 	 valid_r2: -0.763
# 679 of 2000 epoch 	 train_loss: 0.162 	 train_MAPE: 1.74% 	 train_r2: 0.172 	 valid_loss: 0.085 	 valid_MAPE: 0.99% 	 valid_r2: 0.054
# 689 of 2000 epoch 	 train_loss: 0.124 	 train_MAPE: 1.23% 	 train_r2: 0.548 	 valid_loss: 0.119 	 valid_MAPE: 1.38% 	 valid_r2: -1.066
# 699 of 2000 epoch 	 train_loss: 0.112 	 train_MAPE: 1.09% 	 train_r2: 0.628 	 valid_loss: 0.154 	 valid_MAPE: 1.88% 	 valid_r2: -2.738
# 709 of 2000 epoch 	 train_loss: 0.116 	 train_MAPE: 1.14% 	 train_r2: 0.602 	 valid_loss: 0.128 	 valid_MAPE: 1.50% 	 valid_r2: -1.442
# 719 of 2000 epoch 	 train_loss: 0.123 	 train_MAPE: 1.22% 	 train_r2: 0.519 	 valid_loss: 0.101 	 valid_MAPE: 1.15% 	 valid_r2: -0.468
# 729 of 2000 epoch 	 train_loss: 0.145 	 train_MAPE: 1.51% 	 train_r2: 0.301 	 valid_loss: 0.091 	 valid_MAPE: 1.08% 	 valid_r2: -0.146
# 739 of 2000 epoch 	 train_loss: 0.168 	 train_MAPE: 1.81% 	 train_r2: 0.065 	 valid_loss: 0.084 	 valid_MAPE: 0.98% 	 valid_r2: 0.103
# 749 of 2000 epoch 	 train_loss: 0.119 	 train_MAPE: 1.17% 	 train_r2: 0.588 	 valid_loss: 0.131 	 valid_MAPE: 1.56% 	 valid_r2: -1.648
# 759 of 2000 epoch 	 train_loss: 0.111 	 train_MAPE: 1.08% 	 train_r2: 0.639 	 valid_loss: 0.145 	 valid_MAPE: 1.75% 	 valid_r2: -2.162
# 769 of 2000 epoch 	 train_loss: 0.108 	 train_MAPE: 1.03% 	 train_r2: 0.664 	 valid_loss: 0.157 	 valid_MAPE: 1.91% 	 valid_r2: -2.732
# 779 of 2000 epoch 	 train_loss: 0.111 	 train_MAPE: 1.07% 	 train_r2: 0.646 	 valid_loss: 0.157 	 valid_MAPE: 1.94% 	 valid_r2: -2.652
# 789 of 2000 epoch 	 train_loss: 0.125 	 train_MAPE: 1.25% 	 train_r2: 0.512 	 valid_loss: 0.096 	 valid_MAPE: 1.08% 	 valid_r2: -0.222
# 799 of 2000 epoch 	 train_loss: 0.130 	 train_MAPE: 1.33% 	 train_r2: 0.444 	 valid_loss: 0.088 	 valid_MAPE: 1.03% 	 valid_r2: -0.019
# 809 of 2000 epoch 	 train_loss: 0.149 	 train_MAPE: 1.57% 	 train_r2: 0.281 	 valid_loss: 0.090 	 valid_MAPE: 1.07% 	 valid_r2: -0.067
# 819 of 2000 epoch 	 train_loss: 0.160 	 train_MAPE: 1.73% 	 train_r2: 0.171 	 valid_loss: 0.084 	 valid_MAPE: 0.97% 	 valid_r2: 0.149
# 829 of 2000 epoch 	 train_loss: 0.111 	 train_MAPE: 1.09% 	 train_r2: 0.637 	 valid_loss: 0.136 	 valid_MAPE: 1.67% 	 valid_r2: -1.689
# 839 of 2000 epoch 	 train_loss: 0.109 	 train_MAPE: 1.05% 	 train_r2: 0.661 	 valid_loss: 0.153 	 valid_MAPE: 1.92% 	 valid_r2: -2.419
# 849 of 2000 epoch 	 train_loss: 0.109 	 train_MAPE: 1.05% 	 train_r2: 0.664 	 valid_loss: 0.149 	 valid_MAPE: 1.86% 	 valid_r2: -2.116
# 859 of 2000 epoch 	 train_loss: 0.106 	 train_MAPE: 1.03% 	 train_r2: 0.678 	 valid_loss: 0.131 	 valid_MAPE: 1.58% 	 valid_r2: -1.264
# 869 of 2000 epoch 	 train_loss: 0.105 	 train_MAPE: 1.01% 	 train_r2: 0.693 	 valid_loss: 0.137 	 valid_MAPE: 1.68% 	 valid_r2: -1.514
# 879 of 2000 epoch 	 train_loss: 0.105 	 train_MAPE: 1.02% 	 train_r2: 0.675 	 valid_loss: 0.132 	 valid_MAPE: 1.62% 	 valid_r2: -1.391
# 889 of 2000 epoch 	 train_loss: 0.105 	 train_MAPE: 1.01% 	 train_r2: 0.685 	 valid_loss: 0.145 	 valid_MAPE: 1.81% 	 valid_r2: -1.949
# 899 of 2000 epoch 	 train_loss: 0.113 	 train_MAPE: 1.12% 	 train_r2: 0.632 	 valid_loss: 0.166 	 valid_MAPE: 2.12% 	 valid_r2: -2.778
# 909 of 2000 epoch 	 train_loss: 0.105 	 train_MAPE: 1.02% 	 train_r2: 0.680 	 valid_loss: 0.138 	 valid_MAPE: 1.70% 	 valid_r2: -1.524
# 919 of 2000 epoch 	 train_loss: 0.108 	 train_MAPE: 1.05% 	 train_r2: 0.668 	 valid_loss: 0.155 	 valid_MAPE: 1.94% 	 valid_r2: -2.296
# 929 of 2000 epoch 	 train_loss: 0.104 	 train_MAPE: 1.00% 	 train_r2: 0.695 	 valid_loss: 0.122 	 valid_MAPE: 1.44% 	 valid_r2: -0.960
# 939 of 2000 epoch 	 train_loss: 0.105 	 train_MAPE: 1.01% 	 train_r2: 0.687 	 valid_loss: 0.154 	 valid_MAPE: 1.92% 	 valid_r2: -2.333
# 949 of 2000 epoch 	 train_loss: 0.103 	 train_MAPE: 0.99% 	 train_r2: 0.694 	 valid_loss: 0.107 	 valid_MAPE: 1.25% 	 valid_r2: -0.519
# 959 of 2000 epoch 	 train_loss: 0.104 	 train_MAPE: 1.01% 	 train_r2: 0.690 	 valid_loss: 0.154 	 valid_MAPE: 1.96% 	 valid_r2: -2.264
# 969 of 2000 epoch 	 train_loss: 0.102 	 train_MAPE: 0.97% 	 train_r2: 0.695 	 valid_loss: 0.106 	 valid_MAPE: 1.26% 	 valid_r2: -0.454
# 979 of 2000 epoch 	 train_loss: 0.103 	 train_MAPE: 0.99% 	 train_r2: 0.694 	 valid_loss: 0.142 	 valid_MAPE: 1.76% 	 valid_r2: -1.760
# 989 of 2000 epoch 	 train_loss: 0.101 	 train_MAPE: 0.96% 	 train_r2: 0.704 	 valid_loss: 0.109 	 valid_MAPE: 1.29% 	 valid_r2: -0.493
# 999 of 2000 epoch 	 train_loss: 0.101 	 train_MAPE: 0.96% 	 train_r2: 0.705 	 valid_loss: 0.144 	 valid_MAPE: 1.81% 	 valid_r2: -1.908
# 1009 of 2000 epoch 	 train_loss: 0.100 	 train_MAPE: 0.95% 	 train_r2: 0.714 	 valid_loss: 0.128 	 valid_MAPE: 1.55% 	 valid_r2: -1.244
# 1019 of 2000 epoch 	 train_loss: 0.104 	 train_MAPE: 0.99% 	 train_r2: 0.694 	 valid_loss: 0.123 	 valid_MAPE: 1.48% 	 valid_r2: -1.030
# 1029 of 2000 epoch 	 train_loss: 0.101 	 train_MAPE: 0.96% 	 train_r2: 0.704 	 valid_loss: 0.138 	 valid_MAPE: 1.74% 	 valid_r2: -1.671
# 1039 of 2000 epoch 	 train_loss: 0.109 	 train_MAPE: 1.06% 	 train_r2: 0.640 	 valid_loss: 0.164 	 valid_MAPE: 2.11% 	 valid_r2: -2.759
# 1049 of 2000 epoch 	 train_loss: 0.101 	 train_MAPE: 0.96% 	 train_r2: 0.710 	 valid_loss: 0.139 	 valid_MAPE: 1.73% 	 valid_r2: -1.678
# 1059 of 2000 epoch 	 train_loss: 0.100 	 train_MAPE: 0.95% 	 train_r2: 0.712 	 valid_loss: 0.108 	 valid_MAPE: 1.27% 	 valid_r2: -0.451
# 1069 of 2000 epoch 	 train_loss: 0.106 	 train_MAPE: 1.02% 	 train_r2: 0.664 	 valid_loss: 0.164 	 valid_MAPE: 2.10% 	 valid_r2: -2.986
# 1079 of 2000 epoch 	 train_loss: 0.101 	 train_MAPE: 0.96% 	 train_r2: 0.705 	 valid_loss: 0.113 	 valid_MAPE: 1.36% 	 valid_r2: -0.587
# 1089 of 2000 epoch 	 train_loss: 0.102 	 train_MAPE: 0.97% 	 train_r2: 0.698 	 valid_loss: 0.156 	 valid_MAPE: 1.99% 	 valid_r2: -2.421
# 1099 of 2000 epoch 	 train_loss: 0.099 	 train_MAPE: 0.95% 	 train_r2: 0.714 	 valid_loss: 0.110 	 valid_MAPE: 1.30% 	 valid_r2: -0.594
# 1109 of 2000 epoch 	 train_loss: 0.101 	 train_MAPE: 0.96% 	 train_r2: 0.703 	 valid_loss: 0.145 	 valid_MAPE: 1.84% 	 valid_r2: -1.974
# 1119 of 2000 epoch 	 train_loss: 0.099 	 train_MAPE: 0.93% 	 train_r2: 0.717 	 valid_loss: 0.122 	 valid_MAPE: 1.49% 	 valid_r2: -0.990
# 1129 of 2000 epoch 	 train_loss: 0.102 	 train_MAPE: 0.97% 	 train_r2: 0.691 	 valid_loss: 0.149 	 valid_MAPE: 1.88% 	 valid_r2: -2.103
# 1139 of 2000 epoch 	 train_loss: 0.098 	 train_MAPE: 0.94% 	 train_r2: 0.722 	 valid_loss: 0.113 	 valid_MAPE: 1.36% 	 valid_r2: -0.662
# 1149 of 2000 epoch 	 train_loss: 0.100 	 train_MAPE: 0.96% 	 train_r2: 0.709 	 valid_loss: 0.141 	 valid_MAPE: 1.78% 	 valid_r2: -1.862
# 1159 of 2000 epoch 	 train_loss: 0.098 	 train_MAPE: 0.92% 	 train_r2: 0.721 	 valid_loss: 0.121 	 valid_MAPE: 1.46% 	 valid_r2: -0.911
# 1169 of 2000 epoch 	 train_loss: 0.106 	 train_MAPE: 1.01% 	 train_r2: 0.664 	 valid_loss: 0.160 	 valid_MAPE: 2.05% 	 valid_r2: -2.714
# 1179 of 2000 epoch 	 train_loss: 0.099 	 train_MAPE: 0.94% 	 train_r2: 0.711 	 valid_loss: 0.117 	 valid_MAPE: 1.44% 	 valid_r2: -0.906
# 1189 of 2000 epoch 	 train_loss: 0.100 	 train_MAPE: 0.95% 	 train_r2: 0.716 	 valid_loss: 0.141 	 valid_MAPE: 1.76% 	 valid_r2: -1.695
# 1199 of 2000 epoch 	 train_loss: 0.101 	 train_MAPE: 0.96% 	 train_r2: 0.695 	 valid_loss: 0.124 	 valid_MAPE: 1.51% 	 valid_r2: -1.052
# 1209 of 2000 epoch 	 train_loss: 0.098 	 train_MAPE: 0.92% 	 train_r2: 0.716 	 valid_loss: 0.116 	 valid_MAPE: 1.39% 	 valid_r2: -0.752
# 1219 of 2000 epoch 	 train_loss: 0.102 	 train_MAPE: 0.98% 	 train_r2: 0.699 	 valid_loss: 0.156 	 valid_MAPE: 2.02% 	 valid_r2: -2.415
# 1229 of 2000 epoch 	 train_loss: 0.098 	 train_MAPE: 0.92% 	 train_r2: 0.723 	 valid_loss: 0.126 	 valid_MAPE: 1.58% 	 valid_r2: -1.080
# 1239 of 2000 epoch 	 train_loss: 0.118 	 train_MAPE: 1.16% 	 train_r2: 0.564 	 valid_loss: 0.133 	 valid_MAPE: 1.65% 	 valid_r2: -1.333
# 1249 of 2000 epoch 	 train_loss: 0.098 	 train_MAPE: 0.93% 	 train_r2: 0.709 	 valid_loss: 0.125 	 valid_MAPE: 1.51% 	 valid_r2: -1.048
# 1259 of 2000 epoch 	 train_loss: 0.099 	 train_MAPE: 0.94% 	 train_r2: 0.717 	 valid_loss: 0.116 	 valid_MAPE: 1.43% 	 valid_r2: -0.731
# 1269 of 2000 epoch 	 train_loss: 0.098 	 train_MAPE: 0.93% 	 train_r2: 0.721 	 valid_loss: 0.140 	 valid_MAPE: 1.77% 	 valid_r2: -1.705
# 1279 of 2000 epoch 	 train_loss: 0.097 	 train_MAPE: 0.93% 	 train_r2: 0.725 	 valid_loss: 0.118 	 valid_MAPE: 1.44% 	 valid_r2: -0.825
# 1289 of 2000 epoch 	 train_loss: 0.102 	 train_MAPE: 0.97% 	 train_r2: 0.690 	 valid_loss: 0.159 	 valid_MAPE: 2.07% 	 valid_r2: -2.607
# 1299 of 2000 epoch 	 train_loss: 0.098 	 train_MAPE: 0.93% 	 train_r2: 0.712 	 valid_loss: 0.122 	 valid_MAPE: 1.53% 	 valid_r2: -1.010
# 1309 of 2000 epoch 	 train_loss: 0.099 	 train_MAPE: 0.94% 	 train_r2: 0.718 	 valid_loss: 0.110 	 valid_MAPE: 1.33% 	 valid_r2: -0.481
# 1319 of 2000 epoch 	 train_loss: 0.098 	 train_MAPE: 0.93% 	 train_r2: 0.717 	 valid_loss: 0.137 	 valid_MAPE: 1.72% 	 valid_r2: -1.552
# 1329 of 2000 epoch 	 train_loss: 0.097 	 train_MAPE: 0.92% 	 train_r2: 0.727 	 valid_loss: 0.110 	 valid_MAPE: 1.34% 	 valid_r2: -0.459
# 1339 of 2000 epoch 	 train_loss: 0.101 	 train_MAPE: 0.98% 	 train_r2: 0.704 	 valid_loss: 0.119 	 valid_MAPE: 1.49% 	 valid_r2: -0.832
# 1349 of 2000 epoch 	 train_loss: 0.096 	 train_MAPE: 0.91% 	 train_r2: 0.727 	 valid_loss: 0.131 	 valid_MAPE: 1.66% 	 valid_r2: -1.302
# 1359 of 2000 epoch 	 train_loss: 0.097 	 train_MAPE: 0.91% 	 train_r2: 0.727 	 valid_loss: 0.116 	 valid_MAPE: 1.41% 	 valid_r2: -0.670
# 1369 of 2000 epoch 	 train_loss: 0.096 	 train_MAPE: 0.92% 	 train_r2: 0.728 	 valid_loss: 0.112 	 valid_MAPE: 1.38% 	 valid_r2: -0.615
# 1379 of 2000 epoch 	 train_loss: 0.099 	 train_MAPE: 0.94% 	 train_r2: 0.710 	 valid_loss: 0.145 	 valid_MAPE: 1.87% 	 valid_r2: -1.936
# 1389 of 2000 epoch 	 train_loss: 0.097 	 train_MAPE: 0.92% 	 train_r2: 0.722 	 valid_loss: 0.118 	 valid_MAPE: 1.44% 	 valid_r2: -0.787
# 1399 of 2000 epoch 	 train_loss: 0.095 	 train_MAPE: 0.89% 	 train_r2: 0.738 	 valid_loss: 0.120 	 valid_MAPE: 1.48% 	 valid_r2: -0.719
# 1409 of 2000 epoch 	 train_loss: 0.101 	 train_MAPE: 0.97% 	 train_r2: 0.704 	 valid_loss: 0.097 	 valid_MAPE: 1.17% 	 valid_r2: -0.096
# 1419 of 2000 epoch 	 train_loss: 0.097 	 train_MAPE: 0.91% 	 train_r2: 0.725 	 valid_loss: 0.129 	 valid_MAPE: 1.63% 	 valid_r2: -1.187
# 1429 of 2000 epoch 	 train_loss: 0.095 	 train_MAPE: 0.89% 	 train_r2: 0.738 	 valid_loss: 0.118 	 valid_MAPE: 1.46% 	 valid_r2: -0.692
# 1439 of 2000 epoch 	 train_loss: 0.096 	 train_MAPE: 0.91% 	 train_r2: 0.735 	 valid_loss: 0.095 	 valid_MAPE: 1.14% 	 valid_r2: -0.048
# 1449 of 2000 epoch 	 train_loss: 0.098 	 train_MAPE: 0.93% 	 train_r2: 0.722 	 valid_loss: 0.140 	 valid_MAPE: 1.79% 	 valid_r2: -1.703
# 1459 of 2000 epoch 	 train_loss: 0.095 	 train_MAPE: 0.90% 	 train_r2: 0.736 	 valid_loss: 0.114 	 valid_MAPE: 1.42% 	 valid_r2: -0.563
# 1469 of 2000 epoch 	 train_loss: 0.098 	 train_MAPE: 0.92% 	 train_r2: 0.720 	 valid_loss: 0.133 	 valid_MAPE: 1.70% 	 valid_r2: -1.341
# 1479 of 2000 epoch 	 train_loss: 0.097 	 train_MAPE: 0.94% 	 train_r2: 0.724 	 valid_loss: 0.108 	 valid_MAPE: 1.33% 	 valid_r2: -0.378
# 1489 of 2000 epoch 	 train_loss: 0.097 	 train_MAPE: 0.91% 	 train_r2: 0.727 	 valid_loss: 0.123 	 valid_MAPE: 1.55% 	 valid_r2: -0.864
# 1499 of 2000 epoch 	 train_loss: 0.097 	 train_MAPE: 0.92% 	 train_r2: 0.723 	 valid_loss: 0.108 	 valid_MAPE: 1.34% 	 valid_r2: -0.267
# 1509 of 2000 epoch 	 train_loss: 0.098 	 train_MAPE: 0.93% 	 train_r2: 0.717 	 valid_loss: 0.120 	 valid_MAPE: 1.50% 	 valid_r2: -0.731
# 1519 of 2000 epoch 	 train_loss: 0.096 	 train_MAPE: 0.91% 	 train_r2: 0.734 	 valid_loss: 0.108 	 valid_MAPE: 1.35% 	 valid_r2: -0.297
# 1529 of 2000 epoch 	 train_loss: 0.098 	 train_MAPE: 0.93% 	 train_r2: 0.720 	 valid_loss: 0.110 	 valid_MAPE: 1.39% 	 valid_r2: -0.425
# 1539 of 2000 epoch 	 train_loss: 0.096 	 train_MAPE: 0.92% 	 train_r2: 0.727 	 valid_loss: 0.107 	 valid_MAPE: 1.34% 	 valid_r2: -0.321
# 1549 of 2000 epoch 	 train_loss: 0.096 	 train_MAPE: 0.92% 	 train_r2: 0.728 	 valid_loss: 0.108 	 valid_MAPE: 1.37% 	 valid_r2: -0.312
# 1559 of 2000 epoch 	 train_loss: 0.097 	 train_MAPE: 0.93% 	 train_r2: 0.729 	 valid_loss: 0.093 	 valid_MAPE: 1.18% 	 valid_r2: 0.155
# 1569 of 2000 epoch 	 train_loss: 0.097 	 train_MAPE: 0.93% 	 train_r2: 0.726 	 valid_loss: 0.103 	 valid_MAPE: 1.31% 	 valid_r2: -0.144
# 1579 of 2000 epoch 	 train_loss: 0.097 	 train_MAPE: 0.93% 	 train_r2: 0.719 	 valid_loss: 0.093 	 valid_MAPE: 1.17% 	 valid_r2: 0.172
# 1589 of 2000 epoch 	 train_loss: 0.099 	 train_MAPE: 0.95% 	 train_r2: 0.717 	 valid_loss: 0.087 	 valid_MAPE: 1.08% 	 valid_r2: 0.331
# 1599 of 2000 epoch 	 train_loss: 0.100 	 train_MAPE: 0.97% 	 train_r2: 0.703 	 valid_loss: 0.089 	 valid_MAPE: 1.09% 	 valid_r2: 0.304
# 1609 of 2000 epoch 	 train_loss: 0.106 	 train_MAPE: 1.04% 	 train_r2: 0.671 	 valid_loss: 0.096 	 valid_MAPE: 1.22% 	 valid_r2: 0.165
# 1619 of 2000 epoch 	 train_loss: 0.183 	 train_MAPE: 2.01% 	 train_r2: -0.237 	 valid_loss: 0.215 	 valid_MAPE: 2.93% 	 valid_r2: -5.517
# 1629 of 2000 epoch 	 train_loss: 0.161 	 train_MAPE: 1.73% 	 train_r2: 0.080 	 valid_loss: 0.213 	 valid_MAPE: 2.91% 	 valid_r2: -4.971
# 1639 of 2000 epoch 	 train_loss: 0.146 	 train_MAPE: 1.54% 	 train_r2: 0.252 	 valid_loss: 0.218 	 valid_MAPE: 3.00% 	 valid_r2: -5.177
# 1649 of 2000 epoch 	 train_loss: 0.142 	 train_MAPE: 1.49% 	 train_r2: 0.273 	 valid_loss: 0.226 	 valid_MAPE: 3.11% 	 valid_r2: -5.500
# 1659 of 2000 epoch 	 train_loss: 0.117 	 train_MAPE: 1.18% 	 train_r2: 0.543 	 valid_loss: 0.135 	 valid_MAPE: 1.75% 	 valid_r2: -0.977
# 1669 of 2000 epoch 	 train_loss: 0.116 	 train_MAPE: 1.16% 	 train_r2: 0.561 	 valid_loss: 0.124 	 valid_MAPE: 1.58% 	 valid_r2: -0.494
# 1679 of 2000 epoch 	 train_loss: 0.116 	 train_MAPE: 1.16% 	 train_r2: 0.571 	 valid_loss: 0.112 	 valid_MAPE: 1.41% 	 valid_r2: -0.233
# 1689 of 2000 epoch 	 train_loss: 0.167 	 train_MAPE: 1.83% 	 train_r2: -0.015 	 valid_loss: 0.191 	 valid_MAPE: 2.59% 	 valid_r2: -3.387
# 1699 of 2000 epoch 	 train_loss: 0.138 	 train_MAPE: 1.44% 	 train_r2: 0.310 	 valid_loss: 0.172 	 valid_MAPE: 2.31% 	 valid_r2: -2.424
# 1709 of 2000 epoch 	 train_loss: 0.133 	 train_MAPE: 1.38% 	 train_r2: 0.366 	 valid_loss: 0.189 	 valid_MAPE: 2.55% 	 valid_r2: -3.169
# 1719 of 2000 epoch 	 train_loss: 0.130 	 train_MAPE: 1.34% 	 train_r2: 0.392 	 valid_loss: 0.165 	 valid_MAPE: 2.18% 	 valid_r2: -2.118
# 1729 of 2000 epoch 	 train_loss: 0.109 	 train_MAPE: 1.07% 	 train_r2: 0.621 	 valid_loss: 0.094 	 valid_MAPE: 1.17% 	 valid_r2: 0.176
# 1738 of 2000 epoch 	 train_loss: 0.103 	 train_MAPE: 1.00% 	 train_r2: 0.672 	 valid_loss: 0.080 	 valid_MAPE: 0.94% 	 valid_r2: 0.349
# ****************************************** STOP TRAIN  ****************************************
# min train loss: 0.094
# min valid loss: 0.080

# %%
# # 训练 LSTM 模型;  ---- 这里的损失函数是计算Sequence最后一个元素的预测数据和真实数据差异
# model.train()
# epoches = 2000
# train_epoch_loss = 0
# train_epoch_loss_list = []
# valid_smallest_loss = 1
# valid_smallest_epoch = 0
# valid_epoch_loss = 0
# valid_epoch_loss_list = []

# train_batch_count = train_x.shape[0]
# valid_batch_count = valid_x.shape[0]

# h0 = torch.zeros(NUM_LAYERS, TRAIN_BATCH_SIZE, HIDDEN_SIZE).float().to(device)
# c0 = torch.zeros(NUM_LAYERS, TRAIN_BATCH_SIZE, HIDDEN_SIZE).float().to(device)


# for epoch in range(epoches):
#     batch_loss = []
#     train_epoch_loss = 0
#     train_pred_value_list = []
#     train_real_value_list = []
#     train_batch_list = list(range(0,train_batch_count))
#     # random.shuffle(train_batch_list)
#     for step in train_batch_list:
#         train_pred, hn, cn = model(train_x[step], h0, c0)
#         # h0, c0 = hn.detach(), cn.detach()
#         loss = loss_func(train_pred[:,-1,-1], train_y[step][:,-1,-1])                # Compare the all sequences' last element in one batch
#         train_pred_value_list.extend(list(train_pred[:,-1].cpu().detach().flatten().numpy() ))
#         train_real_value_list.extend(list(train_y[step,:,-1,-1].cpu().detach().flatten().numpy() ))
#         optimizer.zero_grad()
#         loss.backward()
#         torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=20, norm_type=2)
#         optimizer.step()
#         batch_loss.append(loss.cpu().data.numpy())
#     # print(batch_loss)
#     train_epoch_loss = np.mean(batch_loss)

#     batch_loss = []
#     valid_epoch_loss = 0
#     valid_pred_value_list = []
#     valid_real_value_list = []
#     for step in range(valid_batch_count):
#         valid_pred, hn, cn = model(valid_x[step], h0, c0)
#         loss = loss_func(valid_pred[:,-1], valid_y[step][:,-1,-1])
#         valid_pred_value_list.extend(list(valid_pred[:,-1].cpu().detach().flatten().numpy()))
#         valid_real_value_list.extend(list(valid_y[step,:,-1,-1].cpu().detach().flatten().numpy()))
#         batch_loss.append(loss.cpu().data.numpy())
#     # print(batch_loss)
#     valid_epoch_loss = np.mean(batch_loss)
    
#     valid_epoch_loss_list.append(valid_epoch_loss)
#     train_epoch_loss_list.append(train_epoch_loss)
    
#     if ((epoch+1) %10) == 0:
#         print("{} of {} epoch   train_loss: {:.3f}   valid_loss: {:.3f}".format(epoch, epoches, train_epoch_loss, valid_epoch_loss))
    
#     if valid_epoch_loss <= 0.16:
#         print("************************** STOP TRAIN ******************************")
#         print("{} of {} epoch   train_loss: {:.3f}   valid_loss: {:.3f}".format(epoch, epoches, train_epoch_loss, valid_epoch_loss))
#         break

# plt.plot(train_epoch_loss_list, 'r-')
# plt.plot(valid_epoch_loss_list, 'b-')
# plt.show()    
# print("min train loss: {:.3f}".format(min(train_epoch_loss_list)))
# print("min valid loss: {:.3f}".format(min(valid_epoch_loss_list)))

# %%
# 这是 train 的预测图形
plt.plot(train_real_value_list, 'r-')
plt.plot(train_pred_value_list, 'b-')
plt.show()
# print(train_real_value_list)

# %%
# 这是 vali的预测图形
plt.plot(valid_real_value_list, 'r-')
plt.plot(valid_pred_value_list, 'b-')
plt.show()

# %%
# 这是 valid 最后一段的数据。误差累积到这里已经很大了。
plt.plot(valid_y[-1,:,-1,-1].cpu().detach().flatten().numpy(), 'r-')
plt.plot(valid_pred[:,-1].cpu().detach().flatten().numpy(), 'b-')
plt.show()
# print(valid_y[-1,:,-1,-1].cpu().detach().flatten().numpy())
# print(valid_pred[:,-1].cpu().detach().flatten().numpy())

# %%
# 用模型预测数据
# 考虑到时序因素，这里的时候误差很大。
model.eval()
test_loss = 0

h0 = torch.zeros(NUM_LAYERS, test_x.shape[1], HIDDEN_SIZE).float().to(device)
c0 = torch.zeros(NUM_LAYERS, test_x.shape[1], HIDDEN_SIZE).float().to(device)

for step in range(test_x.shape[0]):
    pred, hn, cn = model(test_x[step], h0, c0)
    
    loss = loss_func(pred[:,-1,-1], test_y[step][:,-1,-1])               # Compare the all sequences' last element in one batch
    
    if test_x.shape[0] > 1:
        actual_line.append(test_y[step][-1,-1].item())
        pred_line.append(pred[-1,-1].item())
    elif test_x.shape[0] == 1:
        actual_line = test_y[step].cpu().detach().flatten().numpy()        # Only plot the last sequence of test batch
        pred_line   = pred[:,-1].cpu().detach().flatten().numpy()                # Only plot the last sequence of test batch
        
print("Test Loss : {:.3f}".format(loss.data))
print("Prediction: {:.2f}".format(float(pred[-1,-1].data)))
print("Actual:     {:.2f}".format(float(test_y[step][-1,-1].data)))


plt.plot(test_y[step,:,-1,-1].cpu().detach().flatten().numpy(), 'r--')
plt.plot(pred[:,-1].cpu().detach().flatten().numpy(), 'b-')
plt.show()
print(test_y[step,:,-1,-1].cpu().detach().flatten().numpy())
print(pred[:,-1].cpu().detach().flatten().numpy())
# Out:
# Test Loss : 0.090
# Prediction: 6.47
# Actual:     6.40
# [6.41 6.49 6.48 6.37 6.38 6.42 6.42 6.41 6.46 6.42 6.42 6.39 6.38 6.43
#  6.41 6.35 6.37 6.41 6.42 6.39 6.41 6.41 6.4 ]
# [6.4930954 6.5299935 6.593213  6.589557  6.490973  6.47752   6.486087
#  6.465097  6.45767   6.5294704 6.4849195 6.4581294 6.438831  6.459375
#  6.52897   6.5091963 6.4103055 6.442471  6.4865704 6.5071363 6.4491916
#  6.4575663 6.4712934]

# %%
# 保存模型
torch.save(model, 'e:\\LSTM_ATT_CNN3.pkl')

# %%
# 把rolling_data再分割为 train / test 就再预测
# 既然 预测值 和时序相关性很高，可以考虑太早的零星数据对于test影响不大，可以删掉
print(rolling_data.shape)
print(TRAIN_BATCH_SIZE)
print(((rolling_data.shape[0]-1)//TRAIN_BATCH_SIZE)*TRAIN_BATCH_SIZE)
rolling_data = rolling_data[-((rolling_data.shape[0]-1)//TRAIN_BATCH_SIZE)*TRAIN_BATCH_SIZE-1:,]
print(rolling_data.shape)

train = rolling_data[:-1].reshape(-1, TRAIN_BATCH_SIZE, SEQ_LENGTH, X_DIM+Y_DIM*Y_SEQ_LEN)                    # 把数据转成 tain_batch_count x TRAIN_BATCH_SIZE x seq_len x in_dim 格式
test  = rolling_data[-1:].reshape(1, 1, SEQ_LENGTH, X_DIM+Y_DIM*Y_SEQ_LEN)                     # 把数据转成 test_batch_count x TEST_BATCH_SIZE x seq_len x in_dim 格式

train = torch.tensor(train).to(device)
test  = torch.tensor(test).to(device)

train_x, train_y = train[:,:,:,Y_SEQ_LEN:], train[:,:,-1:,0:Y_SEQ_LEN]           # [train_batch_count, batch_size, sequence_length, XorY dimission]
test_x,  test_y  = test[:,:,:, Y_SEQ_LEN:],  test[:,:,-1:,0:Y_SEQ_LEN]           # [train_batch_count, batch_size, sequence_length, XorY dimission]
print(train_x.shape, train_y.shape)
print(test_x.shape, test_y.shape)
print(test_y)
# Out:
# (1263, 25, 136)
# 40
# 1240
# (1241, 25, 136)
# torch.Size([31, 40, 25, 135]) torch.Size([31, 40, 1, 1])
# torch.Size([1, 1, 25, 135]) torch.Size([1, 1, 1, 1])
# tensor([[[[6.4000]]]], device='cuda:0', dtype=torch.float64)

# %%
# 再重新生成模型再 train 模型
model = LSTMModel(input_size=X_DIM, hidden_dim_size=HIDDEN_SIZE, num_layers=NUM_LAYERS, output_size=1).float().to(device)
LR = 1e-6
# loss_func = nn.MSELoss(reduction="mean")
loss_func = RMSELoss
optimizer = torch.optim.Adam(model.parameters(), lr=LR, weight_decay=1e-6)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=1, last_epoch=-1)
model.train()
epoches = 2000

train_epoch_loss_list = []

h0 = torch.zeros(NUM_LAYERS, TRAIN_BATCH_SIZE, HIDDEN_SIZE).float().to(device)
c0 = torch.zeros(NUM_LAYERS, TRAIN_BATCH_SIZE, HIDDEN_SIZE).float().to(device)


for epoch in range(epoches):
    batch_loss = []
    train_epoch_loss = 0
    train_pred_value_list = []
    train_real_value_list = []
    train_batch_list = list(range(0,train_batch_count))
    # random.shuffle(train_batch_list)
    for step in range(0, train_x.shape[0]):
        train_pred, hn, cn = model(train_x[step], h0, c0)
        # h0, c0 = hn.detach(), cn.detach()
        loss = loss_func(train_pred[:,-1,-1], train_y[step][:,-1,-1])                # Compare the all sequences' last element in one batch
        train_pred_value_list.extend(list(train_pred[:,-1,-1].cpu().detach().flatten().numpy() ))
        train_real_value_list.extend(list(train_y[step,:,-1,-1].cpu().detach().flatten().numpy() ))
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=20, norm_type=2)
        optimizer.step()
        batch_loss.append(loss.cpu().data.numpy())

    train_epoch_loss_list.append(np.mean(batch_loss))
    if ((epoch+1) %10) == 0:
        print("{} of {} epoch   train_loss: {:.3f}".format(epoch, epoches, np.mean(batch_loss)))
        
    if np.mean(batch_loss)<0.09:
        print("{} of {} epoch got the smallest epoch train loss: {:.3f}".format(epoch, epoches, np.mean(batch_loss)))
        break
    
plt.plot(train_real_value_list, 'r-')
plt.plot(train_pred_value_list, 'b-')
plt.show()    
print("min train loss: {:.3f}".format(min(train_epoch_loss_list)))
# Out:
# 9 of 2000 epoch   train_loss: 7.659
# 19 of 2000 epoch   train_loss: 2.670
# 29 of 2000 epoch   train_loss: 0.523
# 39 of 2000 epoch   train_loss: 0.501
# 49 of 2000 epoch   train_loss: 0.469
# 59 of 2000 epoch   train_loss: 0.453
# 69 of 2000 epoch   train_loss: 0.438
# 79 of 2000 epoch   train_loss: 0.428
# 89 of 2000 epoch   train_loss: 0.419
# 99 of 2000 epoch   train_loss: 0.409
# 109 of 2000 epoch   train_loss: 0.396
# 119 of 2000 epoch   train_loss: 0.384
# 129 of 2000 epoch   train_loss: 0.371
# 139 of 2000 epoch   train_loss: 0.357
# 149 of 2000 epoch   train_loss: 0.341
# 159 of 2000 epoch   train_loss: 0.323
# 169 of 2000 epoch   train_loss: 0.304
# 179 of 2000 epoch   train_loss: 0.280
# 189 of 2000 epoch   train_loss: 0.258
# 199 of 2000 epoch   train_loss: 0.230
# 209 of 2000 epoch   train_loss: 0.213
# 219 of 2000 epoch   train_loss: 0.223
# 229 of 2000 epoch   train_loss: 0.204
# 239 of 2000 epoch   train_loss: 0.190
# 249 of 2000 epoch   train_loss: 0.185
# 259 of 2000 epoch   train_loss: 0.173
# 269 of 2000 epoch   train_loss: 0.167
# 279 of 2000 epoch   train_loss: 0.155
# 289 of 2000 epoch   train_loss: 0.148
# 299 of 2000 epoch   train_loss: 0.144
# 309 of 2000 epoch   train_loss: 0.140
# 319 of 2000 epoch   train_loss: 0.136
# 329 of 2000 epoch   train_loss: 0.138
# 339 of 2000 epoch   train_loss: 0.145
# 349 of 2000 epoch   train_loss: 0.158
# 359 of 2000 epoch   train_loss: 0.172
# 369 of 2000 epoch   train_loss: 0.198
# 379 of 2000 epoch   train_loss: 0.159
# 389 of 2000 epoch   train_loss: 0.176
# 399 of 2000 epoch   train_loss: 0.129
# 409 of 2000 epoch   train_loss: 0.122
# 419 of 2000 epoch   train_loss: 0.118
# 429 of 2000 epoch   train_loss: 0.112
# 439 of 2000 epoch   train_loss: 0.112
# 449 of 2000 epoch   train_loss: 0.110
# 459 of 2000 epoch   train_loss: 0.110
# 469 of 2000 epoch   train_loss: 0.108
# 479 of 2000 epoch   train_loss: 0.108
# 489 of 2000 epoch   train_loss: 0.106
# 499 of 2000 epoch   train_loss: 0.105
# 509 of 2000 epoch   train_loss: 0.106
# 519 of 2000 epoch   train_loss: 0.104
# 529 of 2000 epoch   train_loss: 0.105
# 539 of 2000 epoch   train_loss: 0.104
# 549 of 2000 epoch   train_loss: 0.113
# 559 of 2000 epoch   train_loss: 0.109
# 569 of 2000 epoch   train_loss: 0.106
# 579 of 2000 epoch   train_loss: 0.114
# 589 of 2000 epoch   train_loss: 0.100
# 599 of 2000 epoch   train_loss: 0.100
# 609 of 2000 epoch   train_loss: 0.099
# 619 of 2000 epoch   train_loss: 0.100
# 629 of 2000 epoch   train_loss: 0.099
# 639 of 2000 epoch   train_loss: 0.099
# 649 of 2000 epoch   train_loss: 0.098
# 659 of 2000 epoch   train_loss: 0.099
# 669 of 2000 epoch   train_loss: 0.098
# 679 of 2000 epoch   train_loss: 0.098
# 689 of 2000 epoch   train_loss: 0.100
# 699 of 2000 epoch   train_loss: 0.118
# 709 of 2000 epoch   train_loss: 0.100
# 719 of 2000 epoch   train_loss: 0.096
# 729 of 2000 epoch   train_loss: 0.095
# 739 of 2000 epoch   train_loss: 0.096
# 749 of 2000 epoch   train_loss: 0.095
# 759 of 2000 epoch   train_loss: 0.095
# 769 of 2000 epoch   train_loss: 0.095
# 779 of 2000 epoch   train_loss: 0.097
# 789 of 2000 epoch   train_loss: 0.122
# 799 of 2000 epoch   train_loss: 0.109
# 809 of 2000 epoch   train_loss: 0.097
# 819 of 2000 epoch   train_loss: 0.097
# 829 of 2000 epoch   train_loss: 0.099
# 839 of 2000 epoch   train_loss: 0.095
# 849 of 2000 epoch   train_loss: 0.096
# 859 of 2000 epoch   train_loss: 0.095
# 869 of 2000 epoch   train_loss: 0.095
# 879 of 2000 epoch   train_loss: 0.095
# 889 of 2000 epoch   train_loss: 0.096
# 899 of 2000 epoch   train_loss: 0.100
# 909 of 2000 epoch   train_loss: 0.102
# 919 of 2000 epoch   train_loss: 0.095
# 929 of 2000 epoch   train_loss: 0.096
# 939 of 2000 epoch   train_loss: 0.100
# 949 of 2000 epoch   train_loss: 0.095
# 959 of 2000 epoch   train_loss: 0.095
# 969 of 2000 epoch   train_loss: 0.094
# 979 of 2000 epoch   train_loss: 0.096
# 989 of 2000 epoch   train_loss: 0.104
# 999 of 2000 epoch   train_loss: 0.105
# 1009 of 2000 epoch   train_loss: 0.104
# 1019 of 2000 epoch   train_loss: 0.102
# 1029 of 2000 epoch   train_loss: 0.102
# 1039 of 2000 epoch   train_loss: 0.109
# 1049 of 2000 epoch   train_loss: 0.102
# 1059 of 2000 epoch   train_loss: 0.109
# 1069 of 2000 epoch   train_loss: 0.106
# 1079 of 2000 epoch   train_loss: 0.154
# 1089 of 2000 epoch   train_loss: 0.178
# 1099 of 2000 epoch   train_loss: 0.189
# 1109 of 2000 epoch   train_loss: 0.170
# 1119 of 2000 epoch   train_loss: 0.152
# 1129 of 2000 epoch   train_loss: 0.124
# 1139 of 2000 epoch   train_loss: 0.114
# 1149 of 2000 epoch   train_loss: 0.119
# 1159 of 2000 epoch   train_loss: 0.110
# 1169 of 2000 epoch   train_loss: 0.106
# 1179 of 2000 epoch   train_loss: 0.102
# 1189 of 2000 epoch   train_loss: 0.098
# 1199 of 2000 epoch   train_loss: 0.096
# 1209 of 2000 epoch   train_loss: 0.095
# 1219 of 2000 epoch   train_loss: 0.096
# 1229 of 2000 epoch   train_loss: 0.095
# 1239 of 2000 epoch   train_loss: 0.095
# 1249 of 2000 epoch   train_loss: 0.098
# 1259 of 2000 epoch   train_loss: 0.098
# 1269 of 2000 epoch   train_loss: 0.092
# 1279 of 2000 epoch   train_loss: 0.093
# 1289 of 2000 epoch   train_loss: 0.092
# 1299 of 2000 epoch   train_loss: 0.094
# 1309 of 2000 epoch   train_loss: 0.094
# 1319 of 2000 epoch   train_loss: 0.096
# 1329 of 2000 epoch   train_loss: 0.100
# 1339 of 2000 epoch   train_loss: 0.092
# 1349 of 2000 epoch   train_loss: 0.093
# 1359 of 2000 epoch   train_loss: 0.092
# 1369 of 2000 epoch   train_loss: 0.092
# 1379 of 2000 epoch   train_loss: 0.092
# 1389 of 2000 epoch   train_loss: 0.091
# 1399 of 2000 epoch   train_loss: 0.092
# 1409 of 2000 epoch   train_loss: 0.091
# 1419 of 2000 epoch   train_loss: 0.093
# 1429 of 2000 epoch   train_loss: 0.093
# 1439 of 2000 epoch   train_loss: 0.094
# 1449 of 2000 epoch   train_loss: 0.094
# 1459 of 2000 epoch   train_loss: 0.092
# 1469 of 2000 epoch   train_loss: 0.095
# 1479 of 2000 epoch   train_loss: 0.095
# 1489 of 2000 epoch   train_loss: 0.096
# 1499 of 2000 epoch   train_loss: 0.092
# 1509 of 2000 epoch   train_loss: 0.091
# 1519 of 2000 epoch   train_loss: 0.092
# 1529 of 2000 epoch   train_loss: 0.092
# 1539 of 2000 epoch   train_loss: 0.091
# 1549 of 2000 epoch   train_loss: 0.107
# 1559 of 2000 epoch   train_loss: 0.100
# 1569 of 2000 epoch   train_loss: 0.101
# 1579 of 2000 epoch   train_loss: 0.104
# 1589 of 2000 epoch   train_loss: 0.095
# 1599 of 2000 epoch   train_loss: 0.099
# 1609 of 2000 epoch   train_loss: 0.118
# 1619 of 2000 epoch   train_loss: 0.116
# 1629 of 2000 epoch   train_loss: 0.136
# 1639 of 2000 epoch   train_loss: 0.118
# 1649 of 2000 epoch   train_loss: 0.122
# 1659 of 2000 epoch   train_loss: 0.182
# 1669 of 2000 epoch   train_loss: 0.139
# 1679 of 2000 epoch   train_loss: 0.108
# 1689 of 2000 epoch   train_loss: 0.093
# 1699 of 2000 epoch   train_loss: 0.093
# 1709 of 2000 epoch   train_loss: 0.091
# 1719 of 2000 epoch   train_loss: 0.090
# 1729 of 2000 epoch   train_loss: 0.092
# 1739 of 2000 epoch   train_loss: 0.089
# 1749 of 2000 epoch   train_loss: 0.090
# 1759 of 2000 epoch   train_loss: 0.091
# 1769 of 2000 epoch   train_loss: 0.090
# 1779 of 2000 epoch   train_loss: 0.100
# 1789 of 2000 epoch   train_loss: 0.098
# 1799 of 2000 epoch   train_loss: 0.092
# 1809 of 2000 epoch   train_loss: 0.093
# 1819 of 2000 epoch   train_loss: 0.092
# 1829 of 2000 epoch   train_loss: 0.091
# 1839 of 2000 epoch   train_loss: 0.089
# 1849 of 2000 epoch   train_loss: 0.088
# 1859 of 2000 epoch   train_loss: 0.088
# 1869 of 2000 epoch   train_loss: 0.087
# 1879 of 2000 epoch   train_loss: 0.089
# 1889 of 2000 epoch   train_loss: 0.088
# 1899 of 2000 epoch   train_loss: 0.088
# 1909 of 2000 epoch   train_loss: 0.088
# 1919 of 2000 epoch   train_loss: 0.087
# 1929 of 2000 epoch   train_loss: 0.088
# 1939 of 2000 epoch   train_loss: 0.104
# 1949 of 2000 epoch   train_loss: 0.093
# 1959 of 2000 epoch   train_loss: 0.096
# 1969 of 2000 epoch   train_loss: 0.093
# 1979 of 2000 epoch   train_loss: 0.089
# 1989 of 2000 epoch   train_loss: 0.090
# 1999 of 2000 epoch   train_loss: 0.094
# min train loss: 0.086

# %%
print(train_pred.shape)
print(train_y.shape)

# print(train_y[-1,-1])
# print(train_pred[-1,-1])
print(train_real_value_list[-1])
print(train_pred_value_list[-1])
# Out:
# torch.Size([40, 1, 1])
# torch.Size([31, 40, 1, 1])
# 6.41
# 6.3406525

# %%
plt.plot(train_real_value_list, 'r-')
plt.plot(train_pred_value_list, 'b-')
plt.show()

# %%
model.eval()

h0 = torch.zeros(NUM_LAYERS, test_x.shape[1], HIDDEN_SIZE).float().to(device)
c0 = torch.zeros(NUM_LAYERS, test_x.shape[1], HIDDEN_SIZE).float().to(device)

pred, hn, cn = model(test_x[-1], h0, c0)

print(test_y.shape)
print(pred.shape)
print("Real: {:.2f}".format(test_y.item()))
print("Pred: {:.2f}".format(pred[:,-1,:].item()))

loss = loss_func(pred[:,-1,-1], test_y[-1][:,-1,-1])
print("loss: {:.3f}".format(loss.item()))
# Out:
# torch.Size([1, 1, 1, 1])
# torch.Size([1, 1, 1])
# Real: 6.40
# Pred: 6.39
# loss: 0.014
